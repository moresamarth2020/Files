# %%
# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)
# Preprocessing Input data
X = np.array([1,2,3,4])
Y = np.array([2,3,4,5])
plt.scatter(X, Y)
plt.show()

# %%
# Building the model
m = 0
c = 0

L = 0.1  # The learning Rate
epochs = 30  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    print("epoch",i)
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    print (m, c)
    # Making predictions
    Y_pred = m*X + c

    plt.scatter(X, Y) 
    plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
    plt.show()
# Out:
# epoch 0
# 2.0 0.7000000000000001
# epoch 1
# 0.6499999999999999 0.26
# epoch 2
# 1.545 0.5830000000000001
# epoch 3
# 0.9359999999999999 0.39390000000000003
# epoch 4
# 1.33505 0.54712
# epoch 5
# 1.0589149999999998 0.470171
# epoch 6
# 1.2354570000000002 0.5466793000000001
# epoch 7
# 1.1089318499999998 0.51961494
# epoch 8
# 1.1857266050000002 0.561226027
# epoch 9
# 1.126523684 0.5561175191
# epoch 10
# 1.1586793984500001 0.58163217328
# epoch 11
# 1.129844214135 0.585966039399
# epoch 12
# 1.142094873233 0.6038507244517001
# epoch 13
# 1.1270272011576499 0.61203314294486
# epoch 14
# 1.130469827948745 0.626112913777063
# epoch 15
# 1.121708629137096 0.6356554170472779
# epoch 16
# 1.1213179769078132 0.6476700190692745
# epoch 17
# 1.1155060020114562 0.657477026801513
# epoch 18
# 1.1135084855935153 0.6682286204354823
# epoch 19
# 1.1091314469855011 0.6778286535516281
# epoch 20
# 1.1065199497314353 0.6876971993485519
# epoch 21
# 1.1028914254600064 0.6968977846131239
# epoch 22
# 1.100105394963435 0.706072514960496
# epoch 23
# 1.0969110450380346 0.7148053144866793
# epoch 24
# 1.094141820237643 0.7233887290703261
# epoch 25
# 1.0912347253460155 0.7316400731374395
# epoch 26
# 1.0885626007582725 0.7396946958369438
# epoch 27
# 1.085871351702392 0.7474744562904188
# epoch 28
# 1.0833270960035946 0.7550438891811391
# epoch 29
# 1.0808145074076332 0.762371563343114

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()
